# %%
import numpy as np
import pandas as pd
import seaborn as sns

from matplotlib import pyplot as plt
# %matplotlib inline
sns.set_style("whitegrid")

# %%
dataframe = pd.read_csv("songs.csv")
dataframe.head()
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist  track_popularity          track_album_id  \
# 0        Ed Sheeran              66.0  2oCs0DGTsRO98Gh5ZSl2Cx
# 1          Maroon 5              67.0  63rPSO264uRjW1X5E6cWv6
# 2      Zara Larsson              70.0  1HoSmj2eLcsrR0vE9gThr4
# 3  The Chainsmokers              60.0  1nqYsOef1yKKuGOVchbsk6
# 4     Lewis Capaldi              69.0  7m7vv9wlQ4i0LFuJiE2zsQ
#
#                                     track_album_name track_album_release_date  \
# 0  I Don't Care (with Justin Bieber) [Loud Luxury...               2019-06-14
# 1                    Memories (Dillon Francis Remix)               2019-12-13
# 2                    All the Time (Don Diablo Remix)               2019-07-05
# 3                        Call You Mine - The Remixes               2019-07-19
# 4            Someone You Loved (Future Humans Remix)               2019-03-05
#
#   playlist_name             playlist_id playlist_genre  ...   key  loudness  \
# 0     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   6.0    -2.634
# 1     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...  11.0    -4.969
# 2     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   1.0    -3.432
# 3     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   7.0    -3.778
# 4     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   1.0    -4.672
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0   1.0       0.0583        0.1020          0.000000    0.0653    0.518
# 1   1.0       0.0373        0.0724          0.004210    0.3570    0.693
# 2   0.0       0.0742        0.0794          0.000023    0.1100    0.613
# 3   1.0       0.1020        0.0287          0.000009    0.2040    0.277
# 4   1.0       0.0359        0.0803          0.000000    0.0833    0.725
#
#      tempo  duration_ms
# 0  122.036     194754.0
# 1   99.972     162600.0
# 2  124.008     176616.0
# 3  121.956     169093.0
# 4  123.976     189052.0
#
# [5 rows x 23 columns]

# %%
print(dataframe.keys())
# Out:
# Index(['track_id', 'track_name', 'track_artist', 'track_popularity',
#        'track_album_id', 'track_album_name', 'track_album_release_date',
#        'playlist_name', 'playlist_id', 'playlist_genre', 'playlist_subgenre',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_ms'],
#       dtype='object')

# %%
pd.isnull(dataframe).sum()
# Out:
# track_id                    10688
# track_name                  10693
# track_artist                    8
# track_popularity            10688
# track_album_id              10688
# track_album_name            10693
# track_album_release_date    10688
# playlist_name               10688
# playlist_id                 10688
# playlist_genre              10688
# playlist_subgenre           10688
# danceability                10688
# energy                      10688
# key                         10688
# loudness                    10688
# mode                        10688
# speechiness                 10688
# acousticness                10688
# instrumentalness            10688
# liveness                    10688
# valence                     10688
# tempo                       10688
# duration_ms                 10688
# dtype: int64

# %%
columns = [ 'track_album_id', 'track_album_name',
                  'track_album_release_date', 'playlist_name', 'playlist_id']
dropped = dataframe.drop(columns=columns)
dropped
# Out:
#                      track_id  \
# 0      6f807x0ima9a1j3VPbc7VN
# 1      0r7CVbZTWZgbTCYdfa2P31
# 2      1z1Hg7Vb0AhHDiEmnDE79l
# 3      75FpbthrwQmzHlBJLuGdC7
# 4      1e8PAfcKUYoKkxPhrHqw4x
# ...                       ...
# 43516                     NaN
# 43517                     NaN
# 43518                     NaN
# 43519                     NaN
# 43520                     NaN
#
#                                               track_name  \
# 0      I Don't Care (with Justin Bieber) - Loud Luxur...
# 1                        Memories - Dillon Francis Remix
# 2                        All the Time - Don Diablo Remix
# 3                      Call You Mine - Keanu Silva Remix
# 4                Someone You Loved - Future Humans Remix
# ...                                                  ...
# 43516                                                NaN
# 43517                                                NaN
# 43518                                                NaN
# 43519                                                NaN
# 43520                                                NaN
#
#                               track_artist  track_popularity playlist_genre  \
# 0                               Ed Sheeran              66.0            pop
# 1                                 Maroon 5              67.0            pop
# 2                             Zara Larsson              70.0            pop
# 3                         The Chainsmokers              60.0            pop
# 4                            Lewis Capaldi              69.0            pop
# ...                                    ...               ...            ...
# 43516                         The Cataracs               NaN            NaN
# 43517                              Qubicon               NaN            NaN
# 43518  Ferry Corsten feat. Jenny Wahlstrom               NaN            NaN
# 43519                       Tegan and Sara               NaN            NaN
# 43520                               Mat Zo               NaN            NaN
#
#       playlist_subgenre  danceability  energy   key  loudness  mode  \
# 0             dance pop         0.748   0.916   6.0    -2.634   1.0
# 1             dance pop         0.726   0.815  11.0    -4.969   1.0
# 2             dance pop         0.675   0.931   1.0    -3.432   0.0
# 3             dance pop         0.718   0.930   7.0    -3.778   1.0
# 4             dance pop         0.650   0.833   1.0    -4.672   1.0
# ...                 ...           ...     ...   ...       ...   ...
# 43516               NaN           NaN     NaN   NaN       NaN   NaN
# 43517               NaN           NaN     NaN   NaN       NaN   NaN
# 43518               NaN           NaN     NaN   NaN       NaN   NaN
# 43519               NaN           NaN     NaN   NaN       NaN   NaN
# 43520               NaN           NaN     NaN   NaN       NaN   NaN
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# 0           0.0583        0.1020          0.000000    0.0653    0.518
# 1           0.0373        0.0724          0.004210    0.3570    0.693
# 2           0.0742        0.0794          0.000023    0.1100    0.613
# 3           0.1020        0.0287          0.000009    0.2040    0.277
# 4           0.0359        0.0803          0.000000    0.0833    0.725
# ...            ...           ...               ...       ...      ...
# 43516          NaN           NaN               NaN       NaN      NaN
# 43517          NaN           NaN               NaN       NaN      NaN
# 43518          NaN           NaN               NaN       NaN      NaN
# 43519          NaN           NaN               NaN       NaN      NaN
# 43520          NaN           NaN               NaN       NaN      NaN
#
#          tempo  duration_ms
# 0      122.036     194754.0
# 1       99.972     162600.0
# 2      124.008     176616.0
# 3      121.956     169093.0
# 4      123.976     189052.0
# ...        ...          ...
# 43516      NaN          NaN
# 43517      NaN          NaN
# 43518      NaN          NaN
# 43519      NaN          NaN
# 43520      NaN          NaN
#
# [43521 rows x 18 columns]

# %%
df_genre_clean = dropped.dropna(subset='playlist_genre')
df_genre_clean = df_genre_clean.dropna(how='any')

# %%
pd.isnull(df_genre_clean).sum()
# Out:
# track_id             0
# track_name           0
# track_artist         0
# track_popularity     0
# playlist_genre       0
# playlist_subgenre    0
# danceability         0
# energy               0
# key                  0
# loudness             0
# mode                 0
# speechiness          0
# acousticness         0
# instrumentalness     0
# liveness             0
# valence              0
# tempo                0
# duration_ms          0
# dtype: int64

# %%
sns.distplot(df_genre_clean['track_popularity']).set_title('Popularity Distribution')
# Out:
# Text(0.5, 1.0, 'Popularity Distribution')

# %%
ax = df_genre_clean['track_popularity'].plot.hist(density= True, bins = 10, color = 'c', alpha = 0.6)
df_genre_clean['track_popularity'].plot.density(ax=ax)
# Out:
# <Axes: ylabel='Density'>

# %%
df_genre_clean.corr()
# Out:
#                   track_popularity  danceability    energy       key  \
# track_popularity          1.000000      0.064754 -0.108984 -0.000405
# danceability              0.064754      1.000000 -0.086074  0.011771
# energy                   -0.108984     -0.086074  1.000000  0.009972
# key                      -0.000405      0.011771  0.009972  1.000000
# loudness                  0.057717      0.025351  0.676662  0.000920
# mode                      0.010553     -0.058711 -0.004778 -0.173981
# speechiness               0.007067      0.181808 -0.032184  0.022462
# acousticness              0.085042     -0.024515 -0.539732  0.004378
# instrumentalness         -0.150003     -0.008658  0.033282  0.006022
# liveness                 -0.054593     -0.123899  0.161317  0.002834
# valence                   0.033278      0.330538  0.151050  0.019933
# tempo                    -0.005538     -0.184132  0.150072 -0.013316
# duration_ms              -0.143634     -0.096922  0.012560  0.015141
#
#                   loudness      mode  speechiness  acousticness  \
# track_popularity  0.057717  0.010553     0.007067      0.085042
# danceability      0.025351 -0.058711     0.181808     -0.024515
# energy            0.676662 -0.004778    -0.032184     -0.539732
# key               0.000920 -0.173981     0.022462      0.004378
# loudness          1.000000 -0.019242     0.010313     -0.361646
# mode             -0.019242  1.000000    -0.063446      0.009399
# speechiness       0.010313 -0.063446     1.000000      0.026168
# acousticness     -0.361646  0.009399     0.026168      1.000000
# instrumentalness -0.147823 -0.006760    -0.103385     -0.006881
# liveness          0.077589 -0.005485     0.055337     -0.077247
# valence           0.053411  0.002567     0.064756     -0.016833
# tempo             0.093761  0.014339     0.044649     -0.112782
# duration_ms      -0.115039  0.015576    -0.089432     -0.081553
#
#                   instrumentalness  liveness   valence     tempo  duration_ms
# track_popularity         -0.150003 -0.054593  0.033278 -0.005538    -0.143634
# danceability             -0.008658 -0.123899  0.330538 -0.184132    -0.096922
# energy                    0.033282  0.161317  0.151050  0.150072     0.012560
# key                       0.006022  0.002834  0.019933 -0.013316     0.015141
# loudness                 -0.147823  0.077589  0.053411  0.093761    -0.115039
# mode                     -0.006760 -0.005485  0.002567  0.014339     0.015576
# speechiness              -0.103385  0.055337  0.064756  0.044649    -0.089432
# acousticness             -0.006881 -0.077247 -0.016833 -0.112782    -0.081553
# instrumentalness          1.000000 -0.005505 -0.175406  0.023303     0.063256
# liveness                 -0.005505  1.000000 -0.020432  0.020887     0.006197
# valence                  -0.175406 -0.020432  1.000000 -0.025639    -0.032292
# tempo                     0.023303  0.020887 -0.025639  1.000000    -0.001347
# duration_ms               0.063256  0.006197 -0.032292 -0.001347     1.000000

# %%
sns.heatmap(df_genre_clean.corr())
# Out:
# <Axes: >

# %%
df_genre_clean.loc[df_genre_clean['track_popularity'] < 55, 'track_popularity'] = 0
df_genre_clean.loc[df_genre_clean['track_popularity'] >= 55, 'track_popularity'] = 1
df_genre_clean.loc[df_genre_clean['track_popularity'] == 1]
# Out:
#                      track_id  \
# 0      6f807x0ima9a1j3VPbc7VN
# 1      0r7CVbZTWZgbTCYdfa2P31
# 2      1z1Hg7Vb0AhHDiEmnDE79l
# 3      75FpbthrwQmzHlBJLuGdC7
# 4      1e8PAfcKUYoKkxPhrHqw4x
# ...                       ...
# 32758  6PUIzlqotEmPuBfjbwYWOB
# 32759  1KtD0xaLAikgIt5tPbteZQ
# 32760  6NdkzOSCLzmyV9Qc4DKhJ2
# 32783  1mzGywacjpeik00PVLBPpF
# 32798  65hRZOQkVjmBdusz1N7aOv
#
#                                               track_name         track_artist  \
# 0      I Don't Care (with Justin Bieber) - Loud Luxur...           Ed Sheeran
# 1                        Memories - Dillon Francis Remix             Maroon 5
# 2                        All the Time - Don Diablo Remix         Zara Larsson
# 3                      Call You Mine - Keanu Silva Remix     The Chainsmokers
# 4                Someone You Loved - Future Humans Remix        Lewis Capaldi
# ...                                                  ...                  ...
# 32758  Summertime Sadness (Lana Del Rey Vs. Cedric Ge...         Lana Del Rey
# 32759              Thinking About You (feat. Ayah Marar)        Calvin Harris
# 32760                         This Is What It Feels Like     Armin van Buuren
# 32783  All of Me (Tiësto's Birthday Treatment Remix) ...          John Legend
# 32798                                     Save The World  Swedish House Mafia
#
#        track_popularity playlist_genre          playlist_subgenre  \
# 0                   1.0            pop                  dance pop
# 1                   1.0            pop                  dance pop
# 2                   1.0            pop                  dance pop
# 3                   1.0            pop                  dance pop
# 4                   1.0            pop                  dance pop
# ...                 ...            ...                        ...
# 32758               1.0            edm  progressive electro house
# 32759               1.0            edm  progressive electro house
# 32760               1.0            edm  progressive electro house
# 32783               1.0            edm  progressive electro house
# 32798               1.0            edm  progressive electro house
#
#        danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0             0.748   0.916   6.0    -2.634   1.0       0.0583      0.102000
# 1             0.726   0.815  11.0    -4.969   1.0       0.0373      0.072400
# 2             0.675   0.931   1.0    -3.432   0.0       0.0742      0.079400
# 3             0.718   0.930   7.0    -3.778   1.0       0.1020      0.028700
# 4             0.650   0.833   1.0    -4.672   1.0       0.0359      0.080300
# ...             ...     ...   ...       ...   ...          ...           ...
# 32758         0.572   0.810   1.0    -5.791   0.0       0.0558      0.015700
# 32759         0.725   0.874   0.0    -3.715   0.0       0.0396      0.002620
# 32760         0.552   0.831   8.0    -5.217   1.0       0.0298      0.039100
# 32783         0.606   0.720   5.0    -6.253   0.0       0.0283      0.000151
# 32798         0.507   0.665   0.0    -7.598   1.0       0.0474      0.014400
#
#        instrumentalness  liveness  valence    tempo  duration_ms
# 0              0.000000    0.0653    0.518  122.036     194754.0
# 1              0.004210    0.3570    0.693   99.972     162600.0
# 2              0.000023    0.1100    0.613  124.008     176616.0
# 3              0.000009    0.2040    0.277  121.956     169093.0
# 4              0.000000    0.0833    0.725  123.976     189052.0
# ...                 ...       ...      ...      ...          ...
# 32758          0.000007    0.1300    0.110  126.052     214912.0
# 32759          0.000412    0.0958    0.748  127.985     247933.0
# 32760          0.000003    0.0632    0.144  129.889     204360.0
# 32783          0.001650    0.0745    0.179  127.986     251613.0
# 32798          0.000000    0.0759    0.400  126.879     213338.0
#
# [11956 rows x 18 columns]

# %% [markdown]
# models

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

from sklearn.metrics import make_scorer, accuracy_score, roc_auc_score
# from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split

# %%
features = ["acousticness", "danceability", "duration_ms", "energy", "instrumentalness", "key", "liveness",
            "mode", "speechiness", "tempo", "valence"]

# %%
dataframe = df_genre_clean
dataframe.head()
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist  track_popularity playlist_genre playlist_subgenre  \
# 0        Ed Sheeran               1.0            pop         dance pop
# 1          Maroon 5               1.0            pop         dance pop
# 2      Zara Larsson               1.0            pop         dance pop
# 3  The Chainsmokers               1.0            pop         dance pop
# 4     Lewis Capaldi               1.0            pop         dance pop
#
#    danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0         0.748   0.916   6.0    -2.634   1.0       0.0583        0.1020
# 1         0.726   0.815  11.0    -4.969   1.0       0.0373        0.0724
# 2         0.675   0.931   1.0    -3.432   0.0       0.0742        0.0794
# 3         0.718   0.930   7.0    -3.778   1.0       0.1020        0.0287
# 4         0.650   0.833   1.0    -4.672   1.0       0.0359        0.0803
#
#    instrumentalness  liveness  valence    tempo  duration_ms
# 0          0.000000    0.0653    0.518  122.036     194754.0
# 1          0.004210    0.3570    0.693   99.972     162600.0
# 2          0.000023    0.1100    0.613  124.008     176616.0
# 3          0.000009    0.2040    0.277  121.956     169093.0
# 4          0.000000    0.0833    0.725  123.976     189052.0

# %%
training = dataframe.sample(frac = 0.8,random_state = 420)
X_train = training[features]
y_train = training['track_popularity']
X_test = dataframe.drop(training.index)[features]

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size = 0.2, random_state = 420)

# %% [markdown]
# logestic

# %%
LR_Model = LogisticRegression()
LR_Model.fit(X_train, y_train)
LR_Predict = LR_Model.predict(X_valid)
LR_Accuracy = accuracy_score(y_valid, LR_Predict)
print("Accuracy: " + str(LR_Accuracy))

LR_AUC = roc_auc_score(y_valid, LR_Predict)
print("AUC: " + str(LR_AUC))
# Out:
# Accuracy: 0.6379211878926327
# AUC: 0.5

# %%
RFC_Model = RandomForestClassifier()
RFC_Model.fit(X_train, y_train)
RFC_Predict = RFC_Model.predict(X_valid)
RFC_Accuracy = accuracy_score(y_valid, RFC_Predict)
print("Accuracy: " + str(RFC_Accuracy))

RFC_AUC = roc_auc_score(y_valid, RFC_Predict)
print("AUC: " + str(RFC_AUC))
# Out:
# Accuracy: 0.7447173043974872
# AUC: 0.6855564561452064

# %%
DT_Model = DecisionTreeClassifier()
DT_Model.fit(X_train, y_train)
DT_Predict = DT_Model.predict(X_valid)
DT_Accuracy = accuracy_score(y_valid, DT_Predict)
print("Accuracy: " + str(DT_Accuracy))

DT_AUC = roc_auc_score(y_valid, DT_Predict)
print("AUC: " + str(DT_AUC))
# Out:
# Accuracy: 0.6640015229392728
# AUC: 0.6515054595501886
