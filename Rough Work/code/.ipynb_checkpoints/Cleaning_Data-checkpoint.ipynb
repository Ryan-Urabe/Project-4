# %%
#Cleaning Song Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# %%
#csv might be too big, might need to create this path.
data = Path('../Resources/songs.csv')
info = pd.read_csv(data)
info.head()
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist  track_popularity          track_album_id  \
# 0        Ed Sheeran              66.0  2oCs0DGTsRO98Gh5ZSl2Cx
# 1          Maroon 5              67.0  63rPSO264uRjW1X5E6cWv6
# 2      Zara Larsson              70.0  1HoSmj2eLcsrR0vE9gThr4
# 3  The Chainsmokers              60.0  1nqYsOef1yKKuGOVchbsk6
# 4     Lewis Capaldi              69.0  7m7vv9wlQ4i0LFuJiE2zsQ
#
#                                     track_album_name track_album_release_date  \
# ...

# %%
columns = ['track_id', 'track_name', 'track_artist', 'track_popularity', 'track_album_id', 'track_album_name',
                  'track_album_release_date', 'playlist_name', 'playlist_id']
dropped = info.drop(columns=columns)
dropped
# Out:
#       playlist_genre playlist_subgenre  danceability  energy   key  loudness  \
# 0                pop         dance pop         0.748   0.916   6.0    -2.634
# 1                pop         dance pop         0.726   0.815  11.0    -4.969
# 2                pop         dance pop         0.675   0.931   1.0    -3.432
# 3                pop         dance pop         0.718   0.930   7.0    -3.778
# 4                pop         dance pop         0.650   0.833   1.0    -4.672
# ...              ...               ...           ...     ...   ...       ...
# 43516            NaN               NaN           NaN     NaN   NaN       NaN
# 43517            NaN               NaN           NaN     NaN   NaN       NaN
# 43518            NaN               NaN           NaN     NaN   NaN       NaN
# 43519            NaN               NaN           NaN     NaN   NaN       NaN
# 43520            NaN               NaN           NaN     NaN   NaN       NaN
#
# ...

# %%
df_genre_clean = dropped.dropna(subset='playlist_genre')
df_genre_clean
# Out:
#       playlist_genre          playlist_subgenre  danceability  energy   key  \
# 0                pop                  dance pop         0.748   0.916   6.0
# 1                pop                  dance pop         0.726   0.815  11.0
# 2                pop                  dance pop         0.675   0.931   1.0
# 3                pop                  dance pop         0.718   0.930   7.0
# 4                pop                  dance pop         0.650   0.833   1.0
# ...              ...                        ...           ...     ...   ...
# 32828            edm  progressive electro house         0.428   0.922   2.0
# 32829            edm  progressive electro house         0.522   0.786   0.0
# 32830            edm  progressive electro house         0.529   0.821   6.0
# 32831            edm  progressive electro house         0.626   0.888   2.0
# 32832            edm  progressive electro house         0.603   0.884   5.0
#
# ...

# %%
df_genre_clean.info()

# %%
df_genre_clean = df_genre_clean.dropna(how='any')
df_genre_clean.info()

# %%
# dfs to potentially add drop_subg & drop_key
drop_subg = df_genre_clean.drop(columns='playlist_subgenre')
drop_subg

# %%
#adding this step in case we do a user input data thingy. might be difficult for regular users to pick a key
#drop_key = drop_subg.drop(columns='key')
#drop_key

# %%
drop_subg.describe()
# Out:
#        danceability        energy           key      loudness          mode  \
# count  32833.000000  32833.000000  32833.000000  32833.000000  32833.000000
# mean       0.654850      0.698619      5.374471     -6.719499      0.565711
# std        0.145085      0.180910      3.611657      2.988436      0.495671
# min        0.000000      0.000175      0.000000    -46.448000      0.000000
# 25%        0.563000      0.581000      2.000000     -8.171000      0.000000
# 50%        0.672000      0.721000      6.000000     -6.166000      1.000000
# 75%        0.761000      0.840000      9.000000     -4.645000      1.000000
# max        0.983000      1.000000     11.000000      1.275000      1.000000
#
#         speechiness  acousticness  instrumentalness      liveness  \
# count  32833.000000  32833.000000      32833.000000  32833.000000
# mean       0.107068      0.175334          0.084747      0.190176
# std        0.101314      0.219633          0.224230      0.154317
# ...

# %%
# get rid of outliers.

# %%
columns = drop_subg.columns.tolist()
columns.remove('playlist_genre')
columns
# Out:
# ['danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'duration_ms']

# %%
#check = drop_subg['danceability']
#for i in check:
    #if i > 0.761:
        #print(i)

# %%
#x = drop_subg['danceability']

#for i in x.index:
    #if x[i] < 0.266 or x[i] > 1.058:
        #x.drop(i, inplace=True)

#print(x)

# %%
#quartiles = drop_subg['danceability'].quantile([.25, .5, .75])
#lower = quartiles[0.25]
#upper = quartiles[0.75]
#iqr = upper-lower
    
#lower_bound = lower - (1.5*iqr)
#upper_bound = upper + (1.5*iqr)
#print(lower_bound, " + ", upper_bound)

# %%
copy = drop_subg.copy()

# %%
copy
# Out:
#       playlist_genre  danceability  energy   key  loudness  mode  speechiness  \
# 0                pop         0.748   0.916   6.0    -2.634   1.0       0.0583
# 1                pop         0.726   0.815  11.0    -4.969   1.0       0.0373
# 2                pop         0.675   0.931   1.0    -3.432   0.0       0.0742
# 3                pop         0.718   0.930   7.0    -3.778   1.0       0.1020
# 4                pop         0.650   0.833   1.0    -4.672   1.0       0.0359
# ...              ...           ...     ...   ...       ...   ...          ...
# 32828            edm         0.428   0.922   2.0    -1.814   1.0       0.0936
# 32829            edm         0.522   0.786   0.0    -4.462   1.0       0.0420
# 32830            edm         0.529   0.821   6.0    -4.899   0.0       0.0481
# 32831            edm         0.626   0.888   2.0    -3.361   1.0       0.1090
# 32832            edm         0.603   0.884   5.0    -4.571   0.0       0.0385
#
# ...

# %%
for i in columns:
    quartiles = drop_subg[i].quantile([.25, .5, .75])
    lower = quartiles[0.25]
    upper = quartiles[0.75]
    iqr = upper-lower
    
    lower_bound = lower - (1.5*iqr)
    upper_bound = upper + (1.5*iqr)
    x = copy[i]
    for info in x.index:
        if x[info] < lower_bound or x[info] > upper_bound:
            copy.drop(info, inplace=True)

# %%
copy
# Out:
#       playlist_genre  danceability  energy   key  loudness  mode  speechiness  \
# 0                pop         0.748   0.916   6.0    -2.634   1.0       0.0583
# 1                pop         0.726   0.815  11.0    -4.969   1.0       0.0373
# 2                pop         0.675   0.931   1.0    -3.432   0.0       0.0742
# 3                pop         0.718   0.930   7.0    -3.778   1.0       0.1020
# 4                pop         0.650   0.833   1.0    -4.672   1.0       0.0359
# ...              ...           ...     ...   ...       ...   ...          ...
# 32824            edm         0.545   0.780   7.0    -4.867   0.0       0.0436
# 32825            edm         0.559   0.916  11.0    -3.050   1.0       0.0626
# 32826            edm         0.645   0.832   2.0    -5.595   1.0       0.0294
# 32828            edm         0.428   0.922   2.0    -1.814   1.0       0.0936
# 32830            edm         0.529   0.821   6.0    -4.899   0.0       0.0481
#
# ...

# %%
drop_subg
# Out:
#       playlist_genre  danceability  energy   key  loudness  mode  speechiness  \
# 0                pop         0.748   0.916   6.0    -2.634   1.0       0.0583
# 1                pop         0.726   0.815  11.0    -4.969   1.0       0.0373
# 2                pop         0.675   0.931   1.0    -3.432   0.0       0.0742
# 3                pop         0.718   0.930   7.0    -3.778   1.0       0.1020
# 4                pop         0.650   0.833   1.0    -4.672   1.0       0.0359
# ...              ...           ...     ...   ...       ...   ...          ...
# 32828            edm         0.428   0.922   2.0    -1.814   1.0       0.0936
# 32829            edm         0.522   0.786   0.0    -4.462   1.0       0.0420
# 32830            edm         0.529   0.821   6.0    -4.899   0.0       0.0481
# 32831            edm         0.626   0.888   2.0    -3.361   1.0       0.1090
# 32832            edm         0.603   0.884   5.0    -4.571   0.0       0.0385
#
# ...

# %%
final = copy.reset_index(drop=True)
final
# Out:
#       playlist_genre  danceability  energy   key  loudness  mode  speechiness  \
# 0                pop         0.748   0.916   6.0    -2.634   1.0       0.0583
# 1                pop         0.726   0.815  11.0    -4.969   1.0       0.0373
# 2                pop         0.675   0.931   1.0    -3.432   0.0       0.0742
# 3                pop         0.718   0.930   7.0    -3.778   1.0       0.1020
# 4                pop         0.650   0.833   1.0    -4.672   1.0       0.0359
# ...              ...           ...     ...   ...       ...   ...          ...
# 19221            edm         0.545   0.780   7.0    -4.867   0.0       0.0436
# 19222            edm         0.559   0.916  11.0    -3.050   1.0       0.0626
# 19223            edm         0.645   0.832   2.0    -5.595   1.0       0.0294
# 19224            edm         0.428   0.922   2.0    -1.814   1.0       0.0936
# 19225            edm         0.529   0.821   6.0    -4.899   0.0       0.0481
#
# ...

# %%
#encoding in actual model?
#final.to_csv('../data/cleaned_data.csv', index=False)

# %% [markdown]
# # Revised Data

# %%
na_df = info.dropna(how='any')
na_df
# Out:
#                      track_id  \
# 0      6f807x0ima9a1j3VPbc7VN
# 1      0r7CVbZTWZgbTCYdfa2P31
# 2      1z1Hg7Vb0AhHDiEmnDE79l
# 3      75FpbthrwQmzHlBJLuGdC7
# 4      1e8PAfcKUYoKkxPhrHqw4x
# ...                       ...
# 32828  7bxnKAamR3snQ1VGLuVfC1
# 32829  5Aevni09Em4575077nkWHz
# 32830  7ImMqPP3Q1yfUHvsdn7wEo
# 32831  2m69mhnfQ1Oq6lGtXuYhgX
# 32832  29zWqhca3zt5NsckZqDf6c
#
#                                               track_name      track_artist  \
# 0      I Don't Care (with Justin Bieber) - Loud Luxur...        Ed Sheeran
# 1                        Memories - Dillon Francis Remix          Maroon 5
# 2                        All the Time - Don Diablo Remix      Zara Larsson
# 3                      Call You Mine - Keanu Silva Remix  The Chainsmokers
# 4                Someone You Loved - Future Humans Remix     Lewis Capaldi
# ...                                                  ...               ...
# ...

# %%
columns = ['track_id', 'track_name', 'track_artist', 'track_album_id', 'track_album_name',
                  'track_album_release_date', 'playlist_name', 'playlist_id', 'tempo', 'duration_ms']
new_columns = info.drop(columns=columns)
dropped2 = new_columns.dropna(how='any')
dropped2
# Out:
#        track_popularity playlist_genre          playlist_subgenre  \
# 0                  66.0            pop                  dance pop
# 1                  67.0            pop                  dance pop
# 2                  70.0            pop                  dance pop
# 3                  60.0            pop                  dance pop
# 4                  69.0            pop                  dance pop
# ...                 ...            ...                        ...
# 32828              42.0            edm  progressive electro house
# 32829              20.0            edm  progressive electro house
# 32830              14.0            edm  progressive electro house
# 32831              15.0            edm  progressive electro house
# 32832              27.0            edm  progressive electro house
#
#        danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0             0.748   0.916   6.0    -2.634   1.0       0.0583      0.102000
# ...

# %%
zero_pop = dropped2[dropped2.track_popularity > 9]

with_pop = zero_pop.reset_index().drop(columns='index')

with_pop
# Out:
#        track_popularity playlist_genre          playlist_subgenre  \
# 0                  66.0            pop                  dance pop
# 1                  67.0            pop                  dance pop
# 2                  70.0            pop                  dance pop
# 3                  60.0            pop                  dance pop
# 4                  69.0            pop                  dance pop
# ...                 ...            ...                        ...
# 27585              42.0            edm  progressive electro house
# 27586              20.0            edm  progressive electro house
# 27587              14.0            edm  progressive electro house
# 27588              15.0            edm  progressive electro house
# 27589              27.0            edm  progressive electro house
#
#        danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0             0.748   0.916   6.0    -2.634   1.0       0.0583      0.102000
# ...

# %%
with_pop['track_popularity'].unique()
# Out:
# array([ 66.,  67.,  70.,  60.,  69.,  62.,  68.,  58.,  63.,  65.,  35.,
#         64.,  30.,  56.,  55.,  59.,  87.,  83.,  61.,  57.,  53.,  34.,
#         74.,  46.,  52.,  45.,  51.,  48.,  39.,  71.,  81.,  85.,  76.,
#         75.,  73.,  79.,  16.,  84.,  37.,  36.,  72.,  77.,  82.,  41.,
#         24.,  18.,  47.,  80.,  96.,  86.,  19.,  27.,  43.,  91.,  42.,
#         21.,  54.,  23.,  40.,  11.,  50.,  10.,  49.,  25.,  95.,  28.,
#         29.,  38.,  17.,  31.,  26.,  32.,  12.,  44.,  13.,  78.,  88.,
#         94.,  22.,  98.,  97.,  90.,  93.,  92.,  33.,  20.,  14.,  15.,
#         89., 100.,  99.])

# %%
import seaborn as sns
sns.distplot(with_pop['track_popularity']).set_title('Popularity Distribution')
# Out:
# C:\Users\MSI\AppData\Local\Temp\ipykernel_17032\2336791797.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(with_pop['track_popularity']).set_title('Popularity Distribution')
# Text(0.5, 1.0, 'Popularity Distribution')

# %%
sns.heatmap(with_pop.corr())
# Out:
# C:\Users\MSI\AppData\Local\Temp\ipykernel_17032\2465409948.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(with_pop.corr())
# <Axes: >

# %%
with_pop.to_csv('../data/tempo_dur_with_pop.csv', index=False)

# %%
pd.isnull(with_pop).sum()
# Out:
# track_popularity     0
# playlist_genre       0
# playlist_subgenre    0
# danceability         0
# energy               0
# key                  0
# loudness             0
# mode                 0
# speechiness          0
# acousticness         0
# instrumentalness     0
# liveness             0
# valence              0
# tempo                0
# duration_ms          0
# dtype: int64

# %%
#ROUGH WORK --------------------------------------------------------------------------------------

# %%
#interim = drop_subg.loc[drop_subg['danceability'] > 0.761 & drop_subg['danceability'] < 0.563]
#interim

# %%
#for i in columns:
   # quartiles = i.quartile([.25, .5, .75])
    #lower = quartiles[0.25]
   # upper = quartiles[0.75]
   # iqr = upper-lower
    
   # lower_bound = lower - (1.5*iqr)
  #  upper_bound = upper + (1.5*iqr)
    
  #  x = drop_subg[]
  #  for i in x.index:
        #if x[i] < 0.563 or x[i] > 0.761:
        #    x.drop(i, inplace=True)
